# %%
import json
import pandas as pd
import matplotlib.pyplot as plt

# %%
import re
def word_in_text(word, text):
    try:
        word = word.lower()
        text = text.lower()
        match = re.search(word, text)
        if match:
            return 1
        return 0
    except:
        return 0

# %%
import sys
#specify path of JSON file, e.g., "C:\\Program Files\\Anaconda2\\tweets.json" for your local location
tweets_data_path = '/Users/macbook/Downloads/Datamine/follower.json'

tweets_data = []
tweets_file = open(tweets_data_path, "r")
count = 0
for line in tweets_file:
    try:
        if (line == '\n'):      # skip empty lines
            continue
        count = count + 1
        tweet = json.loads(line)
        tweets_data.append(tweet)
        if count%100 == 0:
            sys.stdout.write('.')
        if count%7000 == 0:
            sys.stdout.write('\n')
    except Exception as e:
        print(e)
        continue
print(f"\n{count} tweets read.")
# Out:
# .....
# 500 tweets read.

# %%
tweets = pd.DataFrame()
tweets['name'] = list(map(lambda tweet: tweet.get('name', None), tweets_data))
tweets['screen_name'] = list(map(lambda tweet: tweet.get('screen_name', None), tweets_data))
tweets['location'] = list(map(lambda tweet: tweet.get('location', None), tweets_data))
tweets['profile_location'] = list(map(lambda tweet: tweet.get('profile_location', None), tweets_data))
tweets['description'] = list(map(lambda tweet: tweet.get('description', None), tweets_data))
tweets['url'] = list(map(lambda tweet: tweet.get('url', None), tweets_data))
tweets['protected'] = list(map(lambda tweet: tweet.get('protected', None), tweets_data))
tweets['followers_count'] = list(map(lambda tweet: tweet.get('followers_count', None), tweets_data))
tweets['friends_count'] = list(map(lambda tweet: tweet.get('friends_count', None), tweets_data))
tweets['created_at'] = list(map(lambda tweet: tweet.get('created_at', None), tweets_data))
tweets['favourites_count'] = list(map(lambda tweet: tweet.get('favourites_count', None), tweets_data))
tweets['lang'] = list(map(lambda tweet: tweet.get('lang', None), tweets_data))
tweets['profile_background_color'] = list(map(lambda tweet: tweet.get('profile_background_color', None), tweets_data))
tweets['profile_link_color'] = list(map(lambda tweet: tweet.get('profile_link_color', None), tweets_data))
tweets['has_extended_profile'] = list(map(lambda tweet: tweet.get('has_extended_profile', None), tweets_data))
tweets['default_profile'] = list(map(lambda tweet: tweet.get('default_profile', None), tweets_data))
tweets['default_profile_image'] = list(map(lambda tweet: tweet.get('default_profile_image', None), tweets_data))
print(tweets)
# Out:
#                                     name      screen_name  \
# 0                                 シマコ2-6         Shimuzik
# 1    ติ่งสเวทจะเอารถไปจำนำเอาตังค์มาเปย์          Tae_wnb
# 2                              IIwuDaFFK        iiwudaffk
# 3                   กบบดคืออะไรไม่รู้จัก         Bnk48Num
# 4         ดาวเคราะห์โคจรรอบคุณพระอาทิตย์        Gameeiei_
# 5                             จอเอนอ.เจน       Nitipong_H
# 6                                  NB_KK      KK_shirokun
# 7                             AstruminuZ       AstruminuZ
# 8                           ทวิตเล่นไงวะ          NakmonK
# 9                               Nuttanun       chnuttanun
# 10                                   阮阿卿  yoQvC0Ns28VaCap
# 11              เจ้าคอร์กี้มีพิษสุนัขบ้า      Aonafterpig
# 12                               memii ♡         memimime
# 13                            โอ๊ตคนเส้า           oathnp
# 14                              kramlove        2Kramlove
# ...

# %%
logic_tweets = tweets.groupby('name').count()
logic_tweets
# Out:
#                                               screen_name  location  \
# name
# #RD9991                                                 1         1
# ( ˘ᵕ˘ )♡                                                1         1
# (´;ω;`)⁓                                                1         1
# -KJ-                                                    1         1
# ....  .... ....                                         1         1
# .boss                                                   1         1
# 11                                                      1         1
# 12TimeWeCCG                                             1         1
# 160 Go Sweat!                                           1         1
# 333's                                                   1         1
# @AKantubtim                                             1         1
# AAA♡                                                    1         1
# AFDไปทำไมก็โง่อยู่ทุกวัน                                1         1
# ...

# %%
df = logic_tweets['screen_name'].value_counts()
df.to_csv('read.csv',index=True)
df2 = pd.read_csv("read.csv", sep=',', 
                  names = ["Have_or_Not", "Count"])
df2['Have_or_Not'][0] = 'Yes'
df2.to_csv('screen_name_order500.csv',index=True)
df2
# Out:
#   Have_or_Not  Count
# 0         Yes    500

# %%
df = tweets['location'].value_counts()
df.to_csv('read.csv',index=True)
df3 = pd.read_csv("read.csv", sep=',', 
                  names = ["Location", "Count"])
df3.to_csv('location_order500.csv',index=True)
df3
# Out:
#                            Location  Count
# 0                               NaN    249
# 1                 Bangkok, Thailand     39
# 2                          Thailand     29
# 3          กรุงเทพมหานคร, ประเทศไทย     16
# 4                         ประเทศไทย     15
# 5                           Bangkok      6
# 6                             Japan      4
# 7                 Hat Yai, Thailand      2
# 8              Nonthaburi, Thailand      2
# 9               Khon Kaen, Thailand      2
# 10               Bang Khen, Bangkok      2
# 11                            日本 東京      2
# 12                 Bangkok,Thailand      2
# 13     Changwat Si Sa Ket, Thailand      2
# 14             Chiang Mai, Thailand      2
# 15                 Bangkok Thailand      1
# 16       อ.ชะอํา ต.ชะอํา จ.เพชรบุรี      1
# 17     Indonesia,Jawa Timur,Gresik.      1
# 18                             Hell      1
# 19              On top of the world      1
# 20          Maha Sarakham, Thailand      1
# ...

# %%
df = logic_tweets['profile_location'].value_counts()
df.to_csv('read.csv',index=True)
df2 = pd.read_csv("read.csv", sep=',', 
                  names = ["Have_or_Not", "Count"])
df2['Have_or_Not'][0] = 'No'
df2['Have_or_Not'][1] = 'Yes'
df2.to_csv('profile_location_order500.csv',index=True)
df2
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   Have_or_Not  Count
# 0          No    430
# 1         Yes     70

# %%
df = logic_tweets['description'].value_counts()
df.to_csv('read.csv',index=True)
df2 = pd.read_csv("read.csv", sep=',', 
                  names = ["Have_or_Not", "Count"])
df2['Have_or_Not'][0] = 'Yes'
df2.to_csv('description_order500.csv',index=True)
df2
# Out:
#   Have_or_Not  Count
# 0         Yes    500

# %%
df = logic_tweets['url'].value_counts()
df.to_csv('read.csv',index=True)
df2 = pd.read_csv("read.csv", sep=',', 
                  names = ["Have_or_Not", "Count"])
df2['Have_or_Not'][0] = 'No'
df2['Have_or_Not'][1] = 'Yes'
df2.to_csv('url_order500.csv',index=True)
df2
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   Have_or_Not  Count
# 0          No    413
# 1         Yes     87

# %%
df = logic_tweets['protected'].value_counts()
df.to_csv('read.csv',index=True)
df2 = pd.read_csv("read.csv", sep=',', 
                  names = ["Have_or_Not", "Count"])
df2['Have_or_Not'][0] = 'Yes'
df2.to_csv('protected_order500.csv',index=True)
df2
# Out:
#   Have_or_Not  Count
# 0         Yes    500

# %%
df = tweets['followers_count'].value_counts() 
df.to_csv('read.csv',index=True)
df2 = pd.read_csv("read.csv", sep=',', 
                  names = ["Have_Followers", "Count"])
df2.to_csv('followers_count_order500.csv',index=True)
df2
# Out:
#      Have_Followers  Count
# 0                 0     41
# 1                 1     35
# 2                 2     31
# 3                 3     30
# 4                 5     21
# 5                 4     19
# 6                 7     12
# 7                11     10
# 8                12     10
# 9                 6      9
# 10               13      8
# 11                8      8
# 12               10      7
# 13               15      7
# 14               17      6
# 15               20      6
# 16               31      5
# 17               18      5
# 18                9      5
# 19               40      4
# 20               14      4
# 21               37      4
# 22               41      4
# 23               79      4
# 24               48      3
# 25               60      3
# 26               71      3
# 27               53      3
# 28               54      3
# 29               61      3
# ..              ...    ...
# 139             126      1
# 140             128      1
# ...

# %%
df = tweets['friends_count'].value_counts() 
df.to_csv('read.csv',index=True)
df2 = pd.read_csv("read.csv", sep=',', 
                  names = ["Have_Friends", "Count"])
df2.to_csv('friends_count_order500.csv',index=True)
df2
# Out:
#      Have_Friends  Count
# 0              17      8
# 1              39      6
# 2              49      6
# 3              45      6
# 4              22      6
# 5              21      6
# 6              20      6
# 7              38      6
# 8              16      6
# 9              15      6
# 10             83      5
# 11             19      5
# 12            126      4
# 13             77      4
# 14             28      4
# 15             62      4
# 16             94      4
# 17             14      4
# 18             60      4
# 19             98      4
# 20            117      4
# 21             12      4
# 22             51      4
# 23             71      3
# 24            205      3
# 25            103      3
# 26            273      3
# 27            376      3
# 28             44      3
# 29             66      3
# ..            ...    ...
# 272           823      1
# 273           310      1
# 274          1333      1
# 275           307      1
# 276           305      1
# ...

# %%
df = tweets['created_at'].value_counts()
df.to_csv('read.csv',index=True)
df2 = pd.read_csv("read.csv", sep=',', 
                  names = ["created_at", "Count"])
df2.to_csv('created_at_order500.csv',index=True)
df2
# Out:
#                          created_at  Count
# 0    Thu Jun 19 10:20:06 +0000 2014      1
# 1    Sat Mar 12 14:19:14 +0000 2011      1
# 2    Sun Apr 21 15:44:52 +0000 2013      1
# 3    Sat Mar 19 04:41:52 +0000 2011      1
# 4    Sat Mar 06 05:49:23 +0000 2010      1
# 5    Sun Jul 02 04:52:21 +0000 2017      1
# 6    Sun Oct 15 18:53:23 +0000 2017      1
# 7    Mon Jun 20 16:03:35 +0000 2011      1
# 8    Sat Jun 10 14:18:27 +0000 2017      1
# 9    Sat Feb 17 07:02:30 +0000 2018      1
# 10   Thu Jan 04 01:44:19 +0000 2018      1
# 11   Mon Mar 05 09:16:21 +0000 2018      1
# 12   Wed Dec 14 22:14:01 +0000 2016      1
# 13   Thu Oct 19 14:23:48 +0000 2017      1
# 14   Thu Oct 06 14:35:43 +0000 2011      1
# 15   Fri Oct 14 08:52:19 +0000 2016      1
# 16   Tue Dec 29 15:37:01 +0000 2015      1
# 17   Wed Sep 27 23:58:15 +0000 2017      1
# 18   Mon Jun 10 12:00:15 +0000 2013      1
# 19   Fri Jul 17 10:54:21 +0000 2015      1
# 20   Sun Dec 20 10:28:02 +0000 2015      1
# ...

# %%
df = tweets['favourites_count'].value_counts() 
df.to_csv('read.csv',index=True)
df2 = pd.read_csv("read.csv", sep=',', 
                  names = ["favourites_count", "Count"])
df2.to_csv('favourites_count_order500.csv',index=True)
df2
# Out:
#      favourites_count  Count
# 0                   1     11
# 1                   4     10
# 2                   0      7
# 3                   3      7
# 4                   7      6
# 5                   2      6
# 6                   8      6
# 7                   5      6
# 8                   6      6
# 9                  92      5
# 10                 94      5
# 11                 57      4
# 12                 10      4
# 13                 12      4
# 14                 85      4
# 15                 30      4
# 16                 43      4
# 17                 11      3
# 18                 34      3
# 19                 39      3
# 20                 29      3
# 21                 27      3
# 22                 19      3
# 23                 22      3
# 24                 20      3
# 25                172      3
# 26                 17      3
# 27                 64      3
# 28                 62      3
# 29                 14      3
# ..                ...    ...
# ...

# %%
df = tweets['lang'].value_counts()
df.to_csv('read.csv',index=True)
df2 = pd.read_csv("read.csv", sep=',', 
                  names = ["lang", "Count"])
df2.to_csv('lang_order500.csv',index=True)
df2
# Out:
#     lang  Count
# 0     th    285
# 1     en    206
# 2     ja      4
# 3  zh-TW      2
# 4     es      1
# 5     id      1
# 6     ko      1

# %%
df = tweets['profile_background_color'].value_counts() 
df.to_csv('read.csv',index=True)
df2 = pd.read_csv("read.csv", sep=',', 
                  names = ["profile_background_color", "Count"])
df2.to_csv('profile_background_color_order500.csv',index=True)
df2
# Out:
#    profile_background_color  Count
# 0                    F5F8FA    228
# 1                    000000    117
# 2                    C0DEED     88
# 3                    131516      9
# 4                    1A1B1F      8
# 5                    FFFFFF      4
# 6                    ACDED6      3
# 7                    B2DFDA      3
# 8                    0099B9      2
# 9                    3B94D9      2
# 10                   FA743E      2
# 11                   BADFCD      2
# 12                   F5ABB5      2
# 13                   FF6699      2
# 14                   352726      2
# 15                   031C30      1
# 16                   56627C      1
# 17                   F01909      1
# 18                   DB4040      1
# 19                   006400      1
# 20                   D7E7E6      1
# 21                   ED9600      1
# 22                   195C7D      1
# 23                   FAE4BE      1
# 24                   403F3F      1
# 25                   642D8B      1
# ...

# %%
df = tweets['profile_link_color'].value_counts() 
df.to_csv('read.csv',index=True)
df2 = pd.read_csv("read.csv", sep=',', 
                  names = ["Color", "Count"])
df2.to_csv('profile_link_color_order500.csv',index=True)
df2
# Out:
#      Color  Count
# 0   1DA1F2    301
# 1   ABB8C2     21
# 2   1B95E0     20
# 3   E81C4F     19
# 4   F58EA8     16
# 5   91D2FA     11
# 6   19CF86     11
# 7   FAB81E      9
# 8   0084B4      7
# 9   000000      6
# 10  981CEB      5
# 11  2FC2EF      5
# 12  009999      4
# 13  7FDBB6      4
# 14  FF691F      3
# 15  3B94D9      3
# 16  9266CC      3
# 17  DD2E44      3
# 18  B40B43      2
# 19  038543      2
# 20  89C9FA      2
# 21  F5ABB5      2
# 22  006400      2
# 23  D02B55      2
# 24  2CA3A3      1
# 25  5A3546      1
# 26  F57A9B      1
# 27  FA743E      1
# 28  887766      1
# 29  FF0000      1
# ..     ...    ...
# 31  5DA5F6      1
# 32  00B348      1
# 33  72B50D      1
# 34  9D582E      1
# 35  088253      1
# 36  93A644      1
# 37  F18777      1
# 38  FBC2B1      1
# 39  0099CC      1
# 40  58B548      1
# 41  FFAA99      1
# 42  4A913C      1
# 43  A72B2B      1
# 44  777777      1
# 45  E6535B      1
# 46  FF83D8      1
# 47  4DD0E1      1
# 48  0099B9      1
# ...

# %%
df =logic_tweets['has_extended_profile'].value_counts()
df.to_csv('read.csv',index=True)
df2 = pd.read_csv("read.csv", sep=',', 
                  names = ["has_extended_profile", "Count"])
df2['has_extended_profile'][0] = 'Yes'
df2.to_csv('has_extended_profile_order500.csv',index=True)
df2
# Out:
#   has_extended_profile  Count
# 0                  Yes    500

# %%
df = logic_tweets['default_profile'].value_counts()
df.to_csv('read.csv',index=True)
df2 = pd.read_csv("read.csv", sep=',', 
                  names = ["default_profile", "Count"])
df2['default_profile'][0] = 'Yes'
df2.to_csv('default_profile_order500.csv',index=True)
df2
# Out:
#   default_profile  Count
# 0             Yes    500

# %%
logic_tweets['default_profile_image'].value_counts()
df.to_csv('read.csv',index=True)
df2 = pd.read_csv("read.csv", sep=',', 
                  names = ["default_profile_image", "Count"])
df2['default_profile_image'][0] = 'Yes'
df2.to_csv('default_profile_image_order500.csv',index=True)
df2
# Out:
#   default_profile_image  Count
# 0                   Yes    500
